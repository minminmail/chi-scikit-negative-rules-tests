# %%
# generate toy data label 3, 2 features
import numpy as np
import random

from sklearn.datasets import make_moons, make_blobs

# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2)

# %%
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot
import pandas as pd
import numpy as np
# generate 2d classification dataset
f11=np.random.uniform(0,5,120)
f12=np.random.uniform(5,10,100)
f13=np.random.uniform(10,15,80)
f14=np.random.uniform(0,5,50)
f15=np.random.uniform(5,10,60)
f16=np.random.uniform(10,15,70)
f17=np.random.uniform(0,5,100)
f18=np.random.uniform(5,10,110)
f19=np.random.uniform(10,15,90)

f1=np.concatenate((f11,f12,f13,f14,f15,f16,f17,f18,f19))
#print(f1)
f21=np.random.uniform(0,5,120)
f22=np.random.uniform(0,5,100)
f23=np.random.uniform(0,5,80)
f24=np.random.uniform(5,10,50)
f25=np.random.uniform(5,10,60)
f26=np.random.uniform(5,10,70)
f27=np.random.uniform(10,15,100)
f28=np.random.uniform(10,15,110)
f29=np.random.uniform(10,15,90)
f2=np.concatenate((f21,f22,f23,f24,f25,f26,f27,f28,f29))
#print(f2)
X=np.vstack((f1, f2)).T
#print("X is:")
#print(X)

y1=np.full((120, 1), 1)
y2=np.full((100, 1), 2)
y3=np.full((80, 1), 2)
y4=np.full((50, 1), 2)
y5=np.full((60, 1), 3)
y6=np.full((70, 1), 3)
y7=np.full((100, 1), 3)
y8=np.full((110, 1), 1)
y9=np.full((90, 1), 1)
y=np.concatenate((y1,y2,y3,y4,y5,y6,y7,y8,y9))

print("y´s shape is :"+str(y.shape))
#print(y)
print("x´s shape is :"+str(X.shape))

# scatter plot, dots colored by class value

"""
import pandas as pd
d = {'timeIndex': [1, 1, 1, 1, 2, 2, 2], 'isZero': [0,0,0,1,0,0,0]}
df = pd.DataFrame(data=d)
df2 = df.groupby(['timeIndex'])['isZero'].sum()
print(df2)

"""

df = pd.DataFrame(X,columns=['feature1','feature2'])
colors = {1:'red', 2:'blue', 3:'green'}

df.groupby('label')
#D['sq'].groupby([D['vector'].apply(tuple), D['gp']])
df.plot.scatter(x='feature1',y='feature2',color='red',label='1')
df.plot.scatter(x='feature1',y='feature2',color='blue',label='2')
df.plot.scatter(x='feature1',y='feature2',color='green',label='3')
# Out:
# y´s shape is :(780, 1)
# x´s shape is :(780, 2)
